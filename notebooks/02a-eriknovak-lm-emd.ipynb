# %%
# enable automatic reloading of the notebook
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # LM-EMD

# %%
from src.models.model import Seq_LM_EMD

# %%
model = Seq_LM_EMD(
    model="roberta-large-mnli", 
    tokenizer="roberta-large-mnli", 
    num_layers=19,
    distance="emd",
    weight_dist="uniform",
    temporal_type="OPW",
    lang="en",
    reg1=0.01, 
    reg2=0.1,
    nit=100,
)
# Out:
# Some weights of the model checkpoint at roberta-large-mnli were not used when initializing RobertaModel: ['classifier.out_proj.weight', 'classifier.out_proj.bias', 'classifier.dense.bias', 'classifier.dense.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
system_text = 'Munich 1856: Four maps that will change your view of the city'
references = ['Munich 1856: Four maps that will change your view of the city']
model.visualize(system_text, references)

# %% [markdown]
# # Checklist

# %%
from src.utils.checklist.translation import TranslationTemplates
TT = TranslationTemplates()

# %%
system_texts = [TT.jumble('Munich 1856: Four maps that change your view of the city') for i in range(10)]

# %%
system_texts = [
    'view Munich Four that : of 1856 city maps change your the',
    'city the maps change your 1856 that Four : view of Munich',
    'the your : change Four Munich 1856 that view of maps city',
    ': maps Munich your the that Four change city view 1856 of',
    'Four Munich view that city of your 1856 change the maps :',
    'that city maps of your Four 1856 change Munich view the :',
    ': city 1856 your maps view Four the of Munich that change',
    'change your that Four 1856 city maps Munich the view of :',
    'that of your Munich the change city Four 1856 maps view :',
    'maps your that Four : the city change of view Munich 1856'
]

# %%
model.visualize(references[0], system_texts)

# %%
from evaluate import load

# %%
comet_metric = load("comet")
# Out:
# wmt20-comet-da is already in cache.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/erikn/Documents/code/experiments/model-Seq-LM-EMD/notebooks/02a-eriknovak-lm-emd.ipynb Cell 13 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22425552474552227d/home/erikn/Documents/code/experiments/model-Seq-LM-EMD/notebooks/02a-eriknovak-lm-emd.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> comet_metric = load("comet")
#
# File ~/Programs/anaconda3/envs/seq-lm-emd/lib/python3.8/site-packages/evaluate/loading.py:723, in load(path, config_name, module_type, process_id, num_process, cache_dir, experiment_id, keep_in_memory, download_config, download_mode, revision, **init_kwargs)
#     718     raise TypeError(
#     719         f"No module of module type '{module_type}' not found for '{path}' locally, or on the Hugging Face Hub. Found module of module type '{evaluation_instance.module_type}' instead."
#     720     )
#     722 # Download and prepare resources for the metric
# --> 723 evaluation_instance.download_and_prepare(download_config=download_config)
#     725 return evaluation_instance
#
# File ~/Programs/anaconda3/envs/seq-lm-emd/lib/python3.8/site-packages/evaluate/module.py:651, in EvaluationModule.download_and_prepare(self, download_config, dl_manager)
#     645         download_config.force_download = False
#     647     dl_manager = DownloadManager(
#     648         dataset_name=self.name, download_config=download_config, data_dir=self.data_dir
#     649     )
# --> 651 self._download_and_prepare(dl_manager)
#
# File ~/.cache/huggingface/modules/evaluate_modules/metrics/evaluate-metric--comet/cac97c28b6f22b9d6044de2fb74da32873fd9ef2d2c58a8feefc68ef803f1a59/comet.py:135, in COMET._download_and_prepare(self, dl_manager)
#     133 def _download_and_prepare(self, dl_manager):
#     134     if self.config_name == "default":
# --> 135         self.scorer = comet.load_from_checkpoint(comet.download_model("wmt20-comet-da"))
#     136     else:
#     137         self.scorer = comet.load_from_checkpoint(comet.download_model(self.config_name))
#
# File ~/Programs/anaconda3/envs/seq-lm-emd/lib/python3.8/site-packages/comet/models/__init__.py:66, in load_from_checkpoint(checkpoint_path)
#      64         hparams = yaml.load(yaml_file.read(), Loader=yaml.FullLoader)
#      65     model_class = str2model[hparams["class_identifier"]]
# ---> 66     model = model_class.load_from_checkpoint(checkpoint_path, **hparams)
#      67     return model
#      68 else:
#
# File ~/Programs/anaconda3/envs/seq-lm-emd/lib/python3.8/site-packages/pytorch_lightning/core/saving.py:161, in ModelIO.load_from_checkpoint(cls, checkpoint_path, map_location, hparams_file, strict, **kwargs)
#     158 # override the hparams with values that were passed in
#     159 checkpoint[cls.CHECKPOINT_HYPER_PARAMS_KEY].update(kwargs)
# --> 161 model = cls._load_model_state(checkpoint, strict=strict, **kwargs)
#     162 return model
#
# File ~/Programs/anaconda3/envs/seq-lm-emd/lib/python3.8/site-packages/pytorch_lightning/core/saving.py:203, in ModelIO._load_model_state(cls, checkpoint, strict, **cls_kwargs_new)
#     199 if not cls_spec.varkw:
#     200     # filter kwargs according to class init unless it allows any argument via kwargs
#     201     _cls_kwargs = {k: v for k, v in _cls_kwargs.items() if k in cls_init_args_name}
# --> 203 model = cls(**_cls_kwargs)
#     205 # give model a chance to load something
#     206 model.on_load_checkpoint(checkpoint)
#
# File ~/Programs/anaconda3/envs/seq-lm-emd/lib/python3.8/site-packages/comet/models/regression/regression_metric.py:75, in RegressionMetric.__init__(self, nr_frozen_epochs, keep_embeddings_frozen, optimizer, encoder_learning_rate, learning_rate, layerwise_decay, encoder_model, pretrained_model, pool, layer, dropout, batch_size, train_data, validation_data, hidden_sizes, activations, final_activation, load_weights_from_checkpoint)
#      54 def __init__(
#      55     self,
#      56     nr_frozen_epochs: Union[float, int] = 0.3,
#    (...)
#      73     load_weights_from_checkpoint: Optional[str] = None,
#      74 ) -> None:
# ---> 75     super().__init__(
#      76         nr_frozen_epochs,
#      77         keep_embeddings_frozen,
#      78         optimizer,
#      79         encoder_learning_rate,
#      80         learning_rate,
#      81         layerwise_decay,
#      82         encoder_model,
#      83         pretrained_model,
#      84         pool,
#      85         layer,
#      86         dropout,
#      87         batch_size,
#      88         train_data,
#      89         validation_data,
#      90         load_weights_from_checkpoint,
#      91         "regression_metric",
#      92     )
#      93     self.save_hyperparameters()
#      95     self.estimator = FeedForward(
#      96         in_dim=self.encoder.output_units * 6,
#      97         hidden_sizes=self.hparams.hidden_sizes,
#    (...)
#     100         final_activation=self.hparams.final_activation,
#     101     )
#
# File ~/Programs/anaconda3/envs/seq-lm-emd/lib/python3.8/site-packages/comet/models/base.py:120, in CometModel.__init__(self, nr_frozen_epochs, keep_embeddings_frozen, optimizer, encoder_learning_rate, learning_rate, layerwise_decay, encoder_model, pretrained_model, pool, layer, dropout, batch_size, train_data, validation_data, load_weights_from_checkpoint, class_identifier)
#     113     if version.parse(transformers.__version__) < version.parse("4.17.0"):
#     114         raise Exception(
#     115             "XLM-RoBERTa-XL requires transformers>=4.17.0. Your current version is {}".format(
#     116                 transformers.__version__
#     117             )
#     118         )
# --> 120 self.encoder = str2encoder[self.hparams.encoder_model].from_pretrained(
#     121     self.hparams.pretrained_model
#     122 )
#     124 self.epoch_nr = 0
#     125 if self.hparams.layer == "mix":
#
# File ~/Programs/anaconda3/envs/seq-lm-emd/lib/python3.8/site-packages/comet/encoders/xlmr.py:49, in XLMREncoder.from_pretrained(cls, pretrained_model)
#      42 @classmethod
#      43 def from_pretrained(cls, pretrained_model: str) -> Encoder:
#      44     """Function that loads a pretrained encoder from Hugging Face.
#      45     :param pretrained_model: Name of the pretrain model to be loaded.
#      46
#      47     :return: Encoder model
#      48     """
# ---> 49     return XLMREncoder(pretrained_model)
#
# File ~/Programs/anaconda3/envs/seq-lm-emd/lib/python3.8/site-packages/comet/encoders/xlmr.py:36, in XLMREncoder.__init__(self, pretrained_model)
#      34 def __init__(self, pretrained_model: str) -> None:
#      35     super(Encoder, self).__init__()
# ---> 36     self.tokenizer = XLMRobertaTokenizer.from_pretrained(pretrained_model)
#      37     self.model = XLMRobertaModel.from_pretrained(
#      38         pretrained_model, add_pooling_layer=False
#      39     )
#      40     self.model.encoder.output_hidden_states = True
#
# TypeError: 'NoneType' object is not callable

# %%
source = ["Dem Feuer konnte Einhalt geboten werden", "Schulen und Kindergärten wurden eröffnet."]
hypothesis = ["The fire could be stopped", "Schools and kindergartens were open"]
reference = ["They were able to control the fire.", "Schools and kindergartens opened"]
comet_score = comet_metric.compute(predictions=hypothesis, references=reference, sources=source)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/erikn/Documents/code/experiments/model-Seq-LM-EMD/notebooks/02a-eriknovak-lm-emd.ipynb Cell 14 in <cell line: 4>()
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22425552474552227d/home/erikn/Documents/code/experiments/model-Seq-LM-EMD/notebooks/02a-eriknovak-lm-emd.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> hypothesis = ["The fire could be stopped", "Schools and kindergartens were open"]
#       <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22425552474552227d/home/erikn/Documents/code/experiments/model-Seq-LM-EMD/notebooks/02a-eriknovak-lm-emd.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> reference = ["They were able to control the fire.", "Schools and kindergartens opened"]
# ----> <a href='vscode-notebook-cell://ssh-remote%2B7b22686f73744e616d65223a22425552474552227d/home/erikn/Documents/code/experiments/model-Seq-LM-EMD/notebooks/02a-eriknovak-lm-emd.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> comet_score = comet_metric.compute(predictions=hypothesis, references=reference, sources=source)
#
# NameError: name 'comet_metric' is not defined
